# %% [markdown]
# # Process the data

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Study 1

# %%
study1 = pd.read_csv("../01 raw data/study1_raw_data_col_names.csv")          

# recode sex as a meaningful factor name
study1['sex'] = study1['sex'].map({1: 'female', 2: 'male'})

# calculate BMI
study1["BMI"] = study1["weight_kg"] / (study1["height_meters"]**2)

# calculate log(waist/height)
study1["log_WHtR"] = np.log(study1["waist_meters"] / study1["height_meters"])

# calculate average subjective hunger score across the 15 questions
hunger = study1.loc[:,study1.columns.str.startswith("hunger")]
study1["subjective_hunger"] = hunger.mean(axis=1)
# drop the raw hunger scores
study1 = study1.loc[:,~study1.columns.str.startswith('hunger')]

# %%
study1.head()
# Out:
#                       URN  consent age     sex  MCQ1  MCQ2  MCQ3  MCQ4  MCQ5  \
# 0  550455-550446-53904018        1  29  female     1     2     1     2     2
# 1  550455-550446-53903992        1  21  female     1     2     1     2     2
# 2  550455-550446-53904586        1  56  female     1     1     1     1     1
# 3  550455-550446-53904603        1  22  female     1     1     1     2     1
# 4  550455-550446-53905774        1  22  female     1     1     1     2     1
#
#    MCQ6  ...  FCQ25  FCQ26  FCQ27          food  height_meters  weight_kg  \
# 0     1  ...      1      1      1    Chocolate            1.68      75.00
# 1     1  ...      2      1      1        Pizza            1.65      82.55
# 2     1  ...      1      1      1  Sweet things           1.63      57.15
# 3     1  ...      1      1      2    Doughnuts            1.68      68.49
# 4     1  ...      1      1      2         Pizza           1.56      82.20
#
#    waist_meters        BMI  log_WHtR  subjective_hunger
# 0          0.76  26.573129 -0.793231           2.066667
# 1          0.76  30.321396 -0.775212           2.000000
# 2          0.71  21.510030 -0.831070           1.333333
# 3          0.30  24.266582 -1.722767           3.400000
# 4          0.81  33.777120 -0.655407           3.866667
#
# [5 rows x 65 columns]

# %%
study1.to_csv("study1_processed.csv", index=False)

# %% [markdown]
# ## Study 2

# %%
study2 = pd.read_csv("../01 raw data/study2_raw_data_col_names.csv")

# recode sex as a meaningful factor name
study2['sex'] = study2['sex'].map({1: 'male', 2: 'female'})  # NOTE: different from study 1

# calculate BMI
study2["BMI"] = study2["weight_kg"] / (study2["height_meters"]**2)

# calculate log(waist/height)
study2["log_WHtR"] = np.log(study2["waist_meters"] / study2["height_meters"])

# calculate average subjectiuve hunger score across the 15 questions
hunger = study2.loc[:,study2.columns.str.startswith("hunger")]
study2["subjective_hunger"] = hunger.mean(axis=1)
# drop the raw hunger scores
study2 = study2.loc[:,~study2.columns.str.startswith('hunger')]
# Out:
# /Users/benjamv/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py:856: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
study2.head()
# Out:
#                       URN age     sex  WCQ1  WCQ2  WCQ3  WCQ4  WCQ5  WCQ6  \
# 0  542031-542022-53955464  21  female     1     2     1     1     1     2
# 1  542031-542022-53955477  20  female     1     2     2     2     2     2
# 2  542031-542022-53955913  23  female     2     2     2     1     2     1
# 3  542031-542022-53955858  28  female     2     2     2     2     2     2
# 4  542031-542022-53956174  23    male     1     2     1     1     1     2
#
#    WCQ7  ...  FCQ25  FCQ26  FCQ27  \
# 0     1  ...      2      2      2
# 1     2  ...      1      1      1
# 2     1  ...      1      2      1
# 3     2  ...      1      1      1
# 4     1  ...      2      2      2
#
#                                                 food  height_meters  \
# 0                                              Pizza           1.60
# 1  Pizza it would go cold if u didn’t eat it imme...           1.60
# 2                                            Nuggets           1.60
# 3                                             Snacks           1.62
# 4                                             Pizza            1.75
#
#    weight_kg  waist_meters        BMI  log_WHtR  subjective_hunger
# 0       59.0          0.71  23.046875 -0.812494           2.933333
# 1      108.0          0.86  42.187500 -0.620827           4.666667
# 2       95.0          0.91  37.109375 -0.564314           2.800000
# 3       95.0          0.97  36.198750 -0.512885           3.800000
# 4       77.0          0.76  25.142857 -0.834053           3.600000
#
# [5 rows x 60 columns]

# %%
study2.to_csv("study2_processed.csv", index=False)
